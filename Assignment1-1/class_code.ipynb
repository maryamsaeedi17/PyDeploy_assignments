# %%
import json
import requests

# %%
response = requests.get("http://numbersapi.com/13")

# %%
response.text
# Out:
# '13 is the number of Oscar nominations of actress Meryl Streep, who holds the record for the most Oscar nominated actress.'

# %%
response = requests.get("https://fruityvice.com/api/fruit/strawberry")

# %%
response.status_code
# Out:
# 200

# %%
json.loads(response.text)
# Out:
# {'name': 'Strawberry',
#  'id': 3,
#  'family': 'Rosaceae',
#  'order': 'Rosales',
#  'genus': 'Fragaria',
#  'nutritions': {'calories': 29,
#   'fat': 0.4,
#   'sugar': 5.4,
#   'carbohydrates': 5.5,
#   'protein': 0.8}}

# %%
response = requests.get("https://goweather.herokuapp.com/weather/tehran")

# %%
response.status_code
# Out:
# 200

# %%
json.loads(response.text)
# Out:
# {'temperature': '17 °C',
#  'wind': '15 km/h',
#  'description': 'Partly cloudy',
#  'forecast': [{'day': '1', 'temperature': '14 °C', 'wind': '7 km/h'},
#   {'day': '2', 'temperature': '13 °C', 'wind': '11 km/h'},
#   {'day': '3', 'temperature': '13 °C', 'wind': '10 km/h'}]}

# %%
response = requests.get("https://thispersondoesnotexist.com")

# %%
response.status_code
# Out:
# 200

# %%
response.content

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
file_data = np.frombuffer(response.content, dtype="int8")
img = cv2.imdecode(file_data, cv2.IMREAD_UNCHANGED)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()
